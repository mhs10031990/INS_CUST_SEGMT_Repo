# %% [markdown]
# # Use Customer_Segmentation Notebook Template

# %%
# import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans,AgglomerativeClustering,DBSCAN,SpectralClustering
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_samples, silhouette_score
# Out:
# Matplotlib created a temporary cache directory at /tmp/matplotlib-oukh2a3u because the default path (/home/mosaic-ai/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %% [markdown]
# # Read data from Snowflake CUSTOMER_TRANSACTION_MASTER using fosforio sdk

# %%
from fosforio import snowflake
# Out:
# Connection manager service url initialised to http://fdc-project-manager:80/project-manager
# If you need to update its value then update the variable CONNECTION_MANAGER_BASE_URL in os env.

# %%
# To get snowflake connection object with a default snowflake connection created by the user, if available.
#snowflake.get_connection()

# To get snowflake connection object with a specific connection name
snowflake.get_connection(connection_name="FDC_Insurance_Snowflake")
# Out:
# Exception occurred in getting snowflake connection: 'connectionSources'

# %%
# To read a specific dataset published from a snowflake connection
df = snowflake.get_dataframe("CUSTOMER_TRANSACTION_MASTER")

# %%
df_original = df.copy()

# %%
df.shape
# Out:
# (122882, 27)

# %%
df.tail()
# Out:
#                                  CUSTOMER_ID        DATE  AGE     SEX  \
# 122877  3a7ce3d5-0f4b-4575-badc-3553f5440c92  2023-05-01   32    MALE
# 122878  e2a8f308-57eb-4f55-bc13-399378f246d3  2022-12-01   27    MALE
# 122879  599c0e61-9bbc-4e14-bbfd-b07f5a398669  2022-12-01   33  FEMALE
# 122880  77298902-f899-4c3e-9104-06d1736fb089  2023-06-01   33  FEMALE
# 122881  cd75294e-c31f-41b3-b78c-1d3e7322ddcf  2022-12-01   44  FEMALE
#
#        EDUCATION_LEVEL EMPLOYMENT_STATUS      HOBBIES MARITAL_STATUS  \
# 122877     High School        Unemployed      reading         Single
# 122878             PhD        Unemployed      camping         Single
# 122879     High School        Unemployed  video-games         Single
# 122880         College        Unemployed   basketball         Single
# 122881     High School          Employed     exercise        Married
#
#             DEPENDENTS REGISTRATION_DATE  ... PURCHASES  ONEOFF_PURCHASES  \
# 122877   One Dependent        2020-03-12  ...  684.4068          305.7313
# 122878   One Dependent        2009-05-12  ...  535.0963            0.0000
# 122879   One Dependent        2007-02-12  ...    0.0000            0.0000
# 122880   One Dependent        2001-02-12  ...    0.0000            0.0000
# 122881  Two Dependents        2001-02-12  ...    0.0000            0.0000
#
#        INSTALLMENTS_PURCHASES  PURCHASES_FREQUENCY  \
# 122877              339.07230            Very high
# 122878              482.58685            Very high
# 122879                0.00000             Very low
# 122880                0.00000             Very low
# 122881                0.00000             Very low
#
#         ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 122877                         Low                         Very high
# 122878                    Very low                         Very high
# 122879                    Very low                          Very low
# 122880                    Very low                          Very low
# 122881                    Very low                          Very low
#
#         PURCHASES_TRX     PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT
# 122877          21.20   273.352691        242.288921               0.0
# 122878          25.92   474.722440        165.534652               0.0
# 122879           0.00   568.542708        549.300475               0.0
# 122880           0.00   517.588408        544.214360               0.0
# 122881           0.00  1029.696570       1552.899035               0.0
#
# [5 rows x 27 columns]

# %%
to_drop = ['CUSTOMER_ID','DATE','AGE','SEX','EDUCATION_LEVEL','EMPLOYMENT_STATUS','HOBBIES','MARITAL_STATUS','BANK_ACCOUNT_TYPE',
 'DEPENDENTS','REGISTRATION_DATE','PURCHASES_FREQUENCY','ONEOFF_PURCHASES_FREQUENCY','PURCHASES_INSTALLMENTS_FREQUENCY','BALANCE_FREQUENCY']

# %%
df.drop(to_drop, axis= 1, inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122882 entries, 0 to 122881
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   BALANCE                 122882 non-null  float64
#  1   CREDIT_LIMIT            122882 non-null  float64
#  2   CASH_ADVANCE            122882 non-null  float64
#  3   CASH_ADVANCE_FREQUENCY  122882 non-null  float64
#  4   CASH_ADVANCE_TRX        122882 non-null  float64
#  5   PURCHASES               122882 non-null  float64
#  6   ONEOFF_PURCHASES        122882 non-null  float64
#  7   INSTALLMENTS_PURCHASES  122882 non-null  float64
#  8   PURCHASES_TRX           122882 non-null  float64
#  9   PAYMENTS                122882 non-null  float64
#  10  MINIMUM_PAYMENTS        122882 non-null  float64
#  11  PRC_FULL_PAYMENT        122882 non-null  float64
# dtypes: float64(12)
# memory usage: 11.3 MB

# %%
# visualise probability density of all columns
plt.figure(figsize=(10,50))
for i in range(len(df.columns)):
  plt.subplot(17,1,i+1)
  sns.distplot(df[df.columns[i]],kde_kws={"color":"b","lw":3,"label":"KDE"},hist_kws={"color":"g"})
  plt.title(df.columns[i])
plt.tight_layout()
# This is to ignore warning
import warnings
warnings.filterwarnings('ignore')
# Out:
# <ipython-input-12-f2276ffbb5fa>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df.columns[i]],kde_kws={"color":"b","lw":3,"label":"KDE"},hist_kws={"color":"g"})
# <ipython-input-12-f2276ffbb5fa>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df.columns[i]],kde_kws={"color":"b","lw":3,"label":"KDE"},hist_kws={"color":"g"})
# <ipython-input-12-f2276ffbb5fa>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df.columns[i]],kde_kws={"color":"b","lw":3,"label":"KDE"},hist_kws={"color":"g"})
# <ipython-input-12-f2276ffbb5fa>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df.columns[i]],kde_kws={"color":"b","lw":3,"label":"KDE"},hist_kws={"color":"g"})
# <ipython-input-12-f2276ffbb5fa>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df.columns[i]],kde_kws={"color":"b","lw":3,"label":"KDE"},hist_kws={"color":"g"})
# <ipython-input-12-f2276ffbb5fa>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df.columns[i]],kde_kws={"color":"b","lw":3,"label":"KDE"},hist_kws={"color":"g"})
# <ipython-input-12-f2276ffbb5fa>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df.columns[i]],kde_kws={"color":"b","lw":3,"label":"KDE"},hist_kws={"color":"g"})
# <ipython-input-12-f2276ffbb5fa>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df.columns[i]],kde_kws={"color":"b","lw":3,"label":"KDE"},hist_kws={"color":"g"})
# <ipython-input-12-f2276ffbb5fa>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df.columns[i]],kde_kws={"color":"b","lw":3,"label":"KDE"},hist_kws={"color":"g"})
# <ipython-input-12-f2276ffbb5fa>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df.columns[i]],kde_kws={"color":"b","lw":3,"label":"KDE"},hist_kws={"color":"g"})
# <ipython-input-12-f2276ffbb5fa>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df.columns[i]],kde_kws={"color":"b","lw":3,"label":"KDE"},hist_kws={"color":"g"})
# <ipython-input-12-f2276ffbb5fa>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df.columns[i]],kde_kws={"color":"b","lw":3,"label":"KDE"},hist_kws={"color":"g"})

# %%
# find outlier in all columns
for i in df.select_dtypes(include=['float64','int64']).columns:
  max_thresold = df[i].quantile(0.95)
  min_thresold = df[i].quantile(0.05)
  df_no_outlier = df[(df[i] < max_thresold) & (df[i] > min_thresold)].shape
  print(" outlier in ",i,"is" ,int(((df.shape[0]-df_no_outlier[0])/df.shape[0])*100),"%")
# Out:
#  outlier in  BALANCE is 10 %
#  outlier in  CREDIT_LIMIT is 10 %
#  outlier in  CASH_ADVANCE is 55 %
#  outlier in  CASH_ADVANCE_FREQUENCY is 55 %
#  outlier in  CASH_ADVANCE_TRX is 55 %
#  outlier in  PURCHASES is 28 %
#  outlier in  ONEOFF_PURCHASES is 49 %
#  outlier in  INSTALLMENTS_PURCHASES is 49 %
#  outlier in  PURCHASES_TRX is 28 %
#  outlier in  PAYMENTS is 10 %
#  outlier in  MINIMUM_PAYMENTS is 10 %
#  outlier in  PRC_FULL_PAYMENT is 72 %

# %%
scaled_df.shape
# Out:
# (122882, 12)

# %% [markdown]
# ### PCA

# %%
pca = PCA(n_components=2)
principal_components = pca.fit_transform(scaled_df)
pca_df = pd.DataFrame(data=principal_components ,columns=["PCA1","PCA2"])
pca_df
# Out:
#             PCA1      PCA2
# 0       0.197136  1.814406
# 1      -0.316559 -0.338030
# 2      -0.396128 -0.378987
# 3      -0.376358 -0.278053
# 4      -0.267530 -0.292796
# ...          ...       ...
# 122877 -0.799041 -0.826553
# 122878 -0.906897 -0.968390
# 122879 -1.173773  0.945230
# 122880 -1.194497  0.964048
# 122881  0.287719  3.422315
#
# [122882 rows x 2 columns]

# %%
k= range(2,9)
inertia_values= []
silhoutte_scores= []

for i in k:
    print(f'Trying KMean clusttering for k= {i}')
    kmean= KMeans(n_clusters= i, random_state= 42)
    kmean.fit(pca_df)
    inertia_values.append(kmean.inertia_)
    
    sil_score= silhouette_score(pca_df, kmean.labels_)
    silhoutte_scores.append(sil_score)
# Out:
# Trying KMean clusttering for k= 2
# /tmp/pip_packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Trying KMean clusttering for k= 3
# /tmp/pip_packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Trying KMean clusttering for k= 4
# /tmp/pip_packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Trying KMean clusttering for k= 5
# /tmp/pip_packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Trying KMean clusttering for k= 7
# /tmp/pip_packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Trying KMean clusttering for k= 8
# /tmp/pip_packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
with plt.style.context('dark_background'):
    plt.figure(figsize=(9,4))
    plt.title("Elbow Method")

    plt.subplot(1,2,1)
    plt.plot(k, inertia_values, marker= 'o', linestyle= '-')
    plt.xlabel("No of clusters (K)")
    plt.ylabel("Inertia")

    plt.subplot(1,2,2)
    plt.plot(k, silhoutte_scores, marker= 'o', linestyle= '-')
    plt.xlabel("No of clusters (K)")
    plt.ylabel("Silhouette Score")

    plt.show()
# Out:
# <ipython-input-43-014eb2e75c29>:5: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,1)

# %%
k= 4
kmean= KMeans(n_clusters=k, random_state= 42)
kmean.fit(pca_df)
# Out:
# /tmp/pip_packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=4, random_state=42)

# %%
pca_df['Group']= kmean.labels_

# %%
pca_df.columns= ['PC1','PC2','Group']

# %%
with plt.style.context('dark_background'):
    plt.figure(figsize=(10,8))
    sns.scatterplot(x="PC1",y="PC2",hue="Group",data=pca_df,palette='flare')
    plt.title("Groups Visualization")
    plt.show()

# %%
pca_df['Group'].value_counts()
# Out:
# Group
# 0    85997
# 2    20461
# 3    15362
# 1     1062
# Name: count, dtype: int64

# %%
cluster_centers = pd.DataFrame(data=kmean.cluster_centers_,columns=['PC1','PC2'])

# %%
cluster_centers
# Out:
#          PC1       PC2
# 0  -0.793861 -0.405865
# 1  12.722399 -3.938086
# 2   0.953669  2.978182
# 3   2.286775 -1.417736

# %%
cluster_df = pd.concat([df_original,pd.DataFrame({'Cluster':kmean.labels_})],axis=1)

# %%
cluster_df.head()
# Out:
#                             CUSTOMER_ID        DATE  AGE     SEX  \
# 0  PNC32940ed8-682f-4052-92b2-cfdc7f41e  2023-12-01   49  FEMALE
# 1  PNCe415caf5-6212-4f50-a062-c12bf1eea  2024-01-01   34    MALE
# 2  PNC1ef5b665-11ae-40d7-b364-be8fa02b9  2023-02-01   34    MALE
# 3  PNC436a6069-0e61-47f2-96e8-d11c19e4b  2024-04-01   29    MALE
# 4  PNCaaa1c8bb-7289-4c25-a05e-efe26e316  2024-02-01   29    MALE
#
#   EDUCATION_LEVEL EMPLOYMENT_STATUS      HOBBIES MARITAL_STATUS  \
# 0     Undisclosed          Employed  Undisclosed        Married
# 1     Undisclosed        Unemployed  Undisclosed        Married
# 2     Undisclosed        Unemployed  Undisclosed        Married
# 3     Undisclosed        Unemployed  Undisclosed         Single
# 4     Undisclosed        Unemployed  Undisclosed         Single
#
#        DEPENDENTS REGISTRATION_DATE  ... ONEOFF_PURCHASES  \
# 0  Two Dependents        2004-11-12  ...          0.00000
# 1   No Dependents        2023-07-12  ...        819.56020
# 2   No Dependents        2021-11-12  ...        746.10905
# 3   One Dependent        2019-07-12  ...       1603.93000
# 4   One Dependent        2022-09-12  ...       1588.94000
#
#    INSTALLMENTS_PURCHASES PURCHASES_FREQUENCY  ONEOFF_PURCHASES_FREQUENCY  \
# 0                     0.0            Very low                    Very low
# 1                     0.0           Very high                   Very high
# 2                     0.0           Very high                   Very high
# 3                     0.0            Very low                    Very low
# 4                     0.0            Very low                    Very low
#
#    PURCHASES_INSTALLMENTS_FREQUENCY  PURCHASES_TRX     PAYMENTS  \
# 0                          Very low          0.000  3774.789989
# 1                          Very low         11.400   665.611414
# 2                          Very low         10.920   653.170079
# 3                          Very low          0.965     0.000000
# 4                          Very low          1.060     0.000000
#
#    MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  Cluster
# 0       1007.999804          0.214444        2
# 1        589.647700          0.000000        0
# 2        570.829156          0.000000        0
# 3          0.000000          0.000000        0
# 4          0.000000          0.000000        0
#
# [5 rows x 28 columns]

# %%
cluster_1_df = cluster_df[cluster_df["Cluster"]==0]
cluster_1_df
# Out:
#                                  CUSTOMER_ID        DATE  AGE     SEX  \
# 1       PNCe415caf5-6212-4f50-a062-c12bf1eea  2024-01-01   34    MALE
# 2       PNC1ef5b665-11ae-40d7-b364-be8fa02b9  2023-02-01   34    MALE
# 3       PNC436a6069-0e61-47f2-96e8-d11c19e4b  2024-04-01   29    MALE
# 4       PNCaaa1c8bb-7289-4c25-a05e-efe26e316  2024-02-01   29    MALE
# 5       PNCcf3bca5a-b756-486c-882c-dd005b48e  2022-08-01   21    MALE
# ...                                      ...         ...  ...     ...
# 122876  90f9a2e5-d25f-4dcb-9a2d-b8608f760455  2022-11-01   32  FEMALE
# 122877  3a7ce3d5-0f4b-4575-badc-3553f5440c92  2023-05-01   32    MALE
# 122878  e2a8f308-57eb-4f55-bc13-399378f246d3  2022-12-01   27    MALE
# 122879  599c0e61-9bbc-4e14-bbfd-b07f5a398669  2022-12-01   33  FEMALE
# 122880  77298902-f899-4c3e-9104-06d1736fb089  2023-06-01   33  FEMALE
#
#        EDUCATION_LEVEL EMPLOYMENT_STATUS      HOBBIES MARITAL_STATUS  \
# 1          Undisclosed        Unemployed  Undisclosed        Married
# 2          Undisclosed        Unemployed  Undisclosed        Married
# 3          Undisclosed        Unemployed  Undisclosed         Single
# 4          Undisclosed        Unemployed  Undisclosed         Single
# 5          Undisclosed        Unemployed  Undisclosed         Single
# ...                ...               ...          ...            ...
# 122876              JD        Unemployed       hiking         Single
# 122877     High School        Unemployed      reading         Single
# 122878             PhD        Unemployed      camping         Single
# 122879     High School        Unemployed  video-games         Single
# 122880         College        Unemployed   basketball         Single
#
#            DEPENDENTS REGISTRATION_DATE  ... ONEOFF_PURCHASES  \
# 1       No Dependents        2023-07-12  ...        819.56020
# 2       No Dependents        2021-11-12  ...        746.10905
# 3       One Dependent        2019-07-12  ...       1603.93000
# 4       One Dependent        2022-09-12  ...       1588.94000
# 5       No Dependents        2021-06-12  ...         16.80000
# ...               ...               ...  ...              ...
# 122876  One Dependent        2002-08-12  ...        305.73130
# 122877  One Dependent        2020-03-12  ...        305.73130
# 122878  One Dependent        2009-05-12  ...          0.00000
# 122879  One Dependent        2007-02-12  ...          0.00000
# 122880  One Dependent        2001-02-12  ...          0.00000
#
#         INSTALLMENTS_PURCHASES PURCHASES_FREQUENCY  \
# 1                      0.00000           Very high
# 2                      0.00000           Very high
# 3                      0.00000            Very low
# 4                      0.00000            Very low
# 5                      0.00000            Very low
# ...                        ...                 ...
# 122876               291.53880           Very high
# 122877               339.07230           Very high
# 122878               482.58685           Very high
# 122879                 0.00000            Very low
# 122880                 0.00000            Very low
#
#         ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 1                        Very high                          Very low
# 2                        Very high                          Very low
# 3                         Very low                          Very low
# 4                         Very low                          Very low
# 5                         Very low                          Very low
# ...                            ...                               ...
# 122876                     Average                              High
# 122877                         Low                         Very high
# 122878                    Very low                         Very high
# 122879                    Very low                          Very low
# 122880                    Very low                          Very low
#
#         PURCHASES_TRX    PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  Cluster
# 1              11.400  665.611414        589.647700               0.0        0
# 2              10.920  653.170079        570.829156               0.0        0
# 3               0.965    0.000000          0.000000               0.0        0
# 4               1.060    0.000000          0.000000               0.0        0
# 5               0.965  617.284634        227.655850               0.0        0
# ...               ...         ...               ...               ...      ...
# 122876         18.800  270.797993        220.049841               0.0        0
# 122877         21.200  273.352691        242.288921               0.0        0
# 122878         25.920  474.722440        165.534652               0.0        0
# 122879          0.000  568.542708        549.300475               0.0        0
# 122880          0.000  517.588408        544.214360               0.0        0
#
# [85997 rows x 28 columns]

# %%
cluster_2_df = cluster_df[cluster_df["Cluster"]==1]
cluster_2_df
# Out:
#                                  CUSTOMER_ID        DATE  AGE     SEX  \
# 175     PNCadb3e0be-ba25-41f4-bb1b-4d4029a63  2024-03-01   70  FEMALE
# 379     PNC6bf27308-7ad9-4cc2-bca2-9c2a858aa  2024-03-01   70  FEMALE
# 383     PNC34ee0418-8d5f-49ec-b653-55d90625a  2024-04-01   64    MALE
# 410     PNCc19e322c-2530-4475-9778-c46b5d3af  2024-04-01   70  FEMALE
# 555     PNCa0b1e136-f47a-492e-ad3a-8638c3c01  2023-08-01   62    MALE
# ...                                      ...         ...  ...     ...
# 120133  780b903b-df24-48ce-a1e8-df34e5d0368c  2024-04-01   69    MALE
# 122131  dc88d8d8-5177-48a5-b94a-4a7910a0f6a1  2023-01-01   55  FEMALE
# 122132  022af4e7-259f-426a-b3cf-a5dedc0489d4  2022-04-01   55    MALE
# 122133  41dbbd7e-2e94-40ab-8c3a-866481f51690  2022-07-01   55    MALE
# 122426  b8447ed3-5800-428a-9656-addc6385c5f9  2024-03-01   55  FEMALE
#
#        EDUCATION_LEVEL EMPLOYMENT_STATUS      HOBBIES MARITAL_STATUS  \
# 175        Undisclosed           Retired  Undisclosed        Widowed
# 379        Undisclosed           Retired  Undisclosed        Widowed
# 383        Undisclosed           Retired  Undisclosed        Widowed
# 410        Undisclosed           Retired  Undisclosed        Widowed
# 555        Undisclosed           Retired  Undisclosed        Widowed
# ...                ...               ...          ...            ...
# 120133              MD           Retired  video-games        Widowed
# 122131         College          Employed     kayaking        Married
# 122132         Masters          Employed    paintball        Married
# 122133         Masters          Employed      reading        Married
# 122426             PhD          Employed      dancing        Married
#
#            DEPENDENTS REGISTRATION_DATE  ... ONEOFF_PURCHASES  \
# 175     No Dependents        2015-09-12  ...        6587.0928
# 379     No Dependents        2011-10-12  ...        6648.0844
# 383     No Dependents        2020-01-12  ...        8700.4800
# 410     No Dependents        2003-02-12  ...        6648.0844
# 555     No Dependents        2017-03-12  ...       12462.4400
# ...               ...               ...  ...              ...
# 120133  No Dependents        1998-06-12  ...        7322.2432
# 122131  No Dependents        2016-11-12  ...       25188.6040
# 122132  No Dependents        2021-05-12  ...       28900.6088
# 122133  No Dependents        2021-10-12  ...       25586.3188
# 122426  No Dependents        2009-11-12  ...       27442.3212
#
#         INSTALLMENTS_PURCHASES PURCHASES_FREQUENCY  \
# 175                  4784.0924           Very high
# 379                  5445.7222           Very high
# 383                  2508.4750           Very high
# 410                  4911.3289           Very high
# 555                     0.0000           Very high
# ...                        ...                 ...
# 120133               3684.1326           Very high
# 122131                254.0820             Average
# 122132                289.2210             Average
# 122133                254.0820                High
# 122426                294.6270                High
#
#         ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 175                           High                         Very high
# 379                           High                         Very high
# 383                           High                         Very high
# 410                           High                         Very high
# 555                      Very high                          Very low
# ...                            ...                               ...
# 120133                   Very high                           Average
# 122131                     Average                          Very low
# 122132                     Average                          Very low
# 122133                     Average                          Very low
# 122426                     Average                          Very low
#
#         PURCHASES_TRX      PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  \
# 175            137.41  11154.808880       8006.223162           0.00000
# 379            141.94  11154.808880       8815.362737           0.00000
# 383            129.15   8952.529720       3130.044809           0.00000
# 410            160.06  11154.808880       8943.121617           0.00000
# 555            217.00  11628.715570       2000.990921           0.00000
# ...               ...           ...               ...               ...
# 120133         110.21  12438.133302        166.084574           0.63000
# 122131          35.31  31080.030484      12802.099820           0.72375
# 122132          34.65  32431.336157      12802.099820           0.69750
# 122133          30.69  32131.046007      12683.561859           0.79500
# 122426          31.02  31530.465708      12683.561859           0.79500
#
#         Cluster
# 175           1
# 379           1
# 383           1
# 410           1
# 555           1
# ...         ...
# 120133        1
# 122131        1
# 122132        1
# 122133        1
# 122426        1
#
# [1062 rows x 28 columns]

# %%
cluster_3_df = cluster_df[cluster_df["Cluster"]==2]
cluster_3_df
# Out:
#                                  CUSTOMER_ID        DATE  AGE     SEX  \
# 0       PNC32940ed8-682f-4052-92b2-cfdc7f41e  2023-12-01   49  FEMALE
# 14      PNCa15f21bc-df48-4d16-a5b7-23df94fa8  2022-10-01   49  FEMALE
# 16      PNC33c4a97f-d846-48ba-b79b-89baf176e  2023-06-01   49  FEMALE
# 19      PNC17422881-4f07-4c03-8409-fc8497639  2023-05-01   49    MALE
# 34      PNC70cee698-e367-4e58-a695-04e0bb35c  2023-05-01   49    MALE
# ...                                      ...         ...  ...     ...
# 122853  d3e5d939-04fa-4cfe-81ee-4ecff3248b52  2024-04-01   44    MALE
# 122854  4f6fb9d4-be51-4fc1-9bcf-386a9b4fb9f0  2022-06-01   44    MALE
# 122855  5d22b285-bcb9-4daa-b961-c7843bad75f8  2022-05-01   44  FEMALE
# 122857  8e33d093-7672-4f21-9e76-03e75a8c074e  2022-05-01   52  FEMALE
# 122881  cd75294e-c31f-41b3-b78c-1d3e7322ddcf  2022-12-01   44  FEMALE
#
#        EDUCATION_LEVEL EMPLOYMENT_STATUS       HOBBIES MARITAL_STATUS  \
# 0          Undisclosed          Employed   Undisclosed        Married
# 14         Undisclosed          Employed   Undisclosed        Married
# 16         Undisclosed          Employed   Undisclosed        Married
# 19         Undisclosed          Employed   Undisclosed        Married
# 34         Undisclosed          Employed   Undisclosed        Married
# ...                ...               ...           ...            ...
# 122853     High School          Employed     cross-fit        Married
# 122854       Associate          Employed  base-jumping        Married
# 122855             PhD          Employed         chess        Married
# 122857       Associate     Self-Employed       reading        Married
# 122881     High School          Employed      exercise        Married
#
#                       DEPENDENTS REGISTRATION_DATE  ... ONEOFF_PURCHASES  \
# 0                 Two Dependents        2004-11-12  ...           0.0000
# 14                Two Dependents        2022-09-12  ...           0.0000
# 16                Two Dependents        2013-12-12  ...           0.0000
# 19                Two Dependents        1999-05-12  ...           0.0000
# 34                Two Dependents        2014-06-12  ...           0.0000
# ...                          ...               ...  ...              ...
# 122853            Two Dependents        2008-11-12  ...           0.0000
# 122854            Two Dependents        2022-08-12  ...           0.0000
# 122855            Two Dependents        2016-11-12  ...           0.0000
# 122857  Three or More Dependents        2005-05-12  ...          79.8735
# 122881            Two Dependents        2001-02-12  ...           0.0000
#
#         INSTALLMENTS_PURCHASES PURCHASES_FREQUENCY  \
# 0                          0.0            Very low
# 14                         0.0            Very low
# 16                         0.0            Very low
# 19                         0.0            Very low
# 34                         0.0            Very low
# ...                        ...                 ...
# 122853                     0.0            Very low
# 122854                     0.0            Very low
# 122855                     0.0            Very low
# 122857                  1476.6                 Low
# 122881                     0.0            Very low
#
#         ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                         Very low                          Very low
# 14                        Very low                          Very low
# 16                        Very low                          Very low
# 19                        Very low                          Very low
# 34                        Very low                          Very low
# ...                            ...                               ...
# 122853                    Very low                          Very low
# 122854                    Very low                          Very low
# 122855                    Very low                          Very low
# 122857                    Very low                               Low
# 122881                    Very low                          Very low
#
#         PURCHASES_TRX     PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  \
# 0                0.00  3774.789989       1007.999804          0.214444
# 14               0.00  3774.789989        997.276402          0.204444
# 16               0.00  3897.880967       1109.872125          0.206666
# 19               0.00  3815.820315       1109.872125          0.204444
# 34               0.00  4308.184227       1168.850837          0.235555
# ...               ...          ...               ...               ...
# 122853           0.00  1121.827315       1509.762951          0.000000
# 122854           0.00   986.340925       1538.520340          0.000000
# 122855           0.00  1018.857658       1509.762951          0.000000
# 122857           7.36  6448.450204       1932.687351          0.000000
# 122881           0.00  1029.696570       1552.899035          0.000000
#
#         Cluster
# 0             2
# 14            2
# 16            2
# 19            2
# 34            2
# ...         ...
# 122853        2
# 122854        2
# 122855        2
# 122857        2
# 122881        2
#
# [20461 rows x 28 columns]

# %%
cluster_4_df = cluster_df[cluster_df["Cluster"] == 3]
cluster_4_df
# Out:
#                                  CUSTOMER_ID        DATE  AGE     SEX  \
# 10      PNCa3755563-44e5-4e81-9e6a-fc6ff0da9  2024-04-01   67  FEMALE
# 26      PNCb39f76c8-4554-4f8c-8075-574daec81  2024-05-01   49  FEMALE
# 28      PNCe0fcf2b9-0402-416e-9b05-3ef66270c  2022-04-01   67  FEMALE
# 54      PNC3c95c9c9-efed-44d2-9af6-5e8acada5  2023-03-01   36    MALE
# 55      PNCa981082e-046f-41d4-890e-61035dbdf  2023-11-01   36    MALE
# ...                                      ...         ...  ...     ...
# 122757  35aae655-5111-41cc-bdda-f57e0685ee23  2022-09-01   36  FEMALE
# 122758  e2dabec5-6d12-49fb-a843-31225fbfb500  2023-06-01   36  FEMALE
# 122784  cefe5ad0-b9e2-4e2b-9bb2-d74caf9d6562  2022-12-01   43    MALE
# 122795  e1f9206a-d67e-4ba8-a47f-41101e06eb29  2022-11-01   50    MALE
# 122796  f86ce20f-72cd-40a7-8033-a199da53f424  2022-12-01   50    MALE
#
#        EDUCATION_LEVEL EMPLOYMENT_STATUS      HOBBIES MARITAL_STATUS  \
# 10         Undisclosed           Retired  Undisclosed        Widowed
# 26         Undisclosed        Unemployed  Undisclosed         Single
# 28         Undisclosed           Retired  Undisclosed        Widowed
# 54         Undisclosed        Unemployed  Undisclosed         Single
# 55         Undisclosed        Unemployed  Undisclosed         Single
# ...                ...               ...          ...            ...
# 122757         Masters        Unemployed  board-games         Single
# 122758     High School        Unemployed     yachting         Single
# 122784         Masters        Unemployed     sleeping         Single
# 122795         College        Unemployed      dancing         Single
# 122796         College        Unemployed         polo         Single
#
#             DEPENDENTS REGISTRATION_DATE  ... ONEOFF_PURCHASES  \
# 10       No Dependents        2018-05-12  ...       6722.76150
# 26      Two Dependents        2015-04-12  ...       2625.24150
# 28       No Dependents        2003-03-12  ...       6082.49850
# 54      Two Dependents        2021-06-12  ...        394.76240
# 55      Two Dependents        2019-04-12  ...        405.26140
# ...                ...               ...  ...              ...
# 122757  Two Dependents        2018-09-12  ...       2103.34750
# 122758  Two Dependents        2009-09-12  ...       2136.55825
# 122784  Two Dependents        2019-09-12  ...       2333.93880
# 122795   No Dependents        2022-03-12  ...          0.00000
# 122796   No Dependents        2000-02-12  ...          0.00000
#
#         INSTALLMENTS_PURCHASES PURCHASES_FREQUENCY  \
# 10                    626.4258           Very high
# 26                    653.1616           Very high
# 28                    633.3096           Very high
# 54                   1855.4076                High
# 55                   1821.0482           Very high
# ...                        ...                 ...
# 122757               2154.8100           Very high
# 122758               1980.3730           Very high
# 122784               1273.0432           Very high
# 122795               2361.5572           Very high
# 122796               2412.8954           Very high
#
#         ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 10                       Very high                         Very high
# 26                             Low                         Very high
# 28                       Very high                         Very high
# 54                        Very low                              High
# 55                        Very low                              High
# ...                            ...                               ...
# 122757                   Very high                         Very high
# 122758                   Very high                         Very high
# 122784                   Very high                         Very high
# 122795                    Very low                         Very high
# 122796                    Very low                         Very high
#
#         PURCHASES_TRX     PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  \
# 10             59.520  6862.659474        204.998200           1.00000
# 26             26.910   638.676873        446.088382           0.26750
# 28             61.760  5782.426038        186.181940           1.00000
# 54             24.700  1713.847635        268.717645           0.09000
# 55             27.560  1738.686007        271.229025           0.08625
# ...               ...          ...               ...               ...
# 122757         69.345  4128.273225        171.600284           0.00000
# 122758         62.980  4051.823720        198.000328           0.00000
# 122784         68.080  4766.566222        219.075443           0.00000
# 122795         37.720  2781.542766        153.226966           1.00000
# 122796         43.460  2861.015417        151.579365           0.92000
#
#         Cluster
# 10            3
# 26            3
# 28            3
# 54            3
# 55            3
# ...         ...
# 122757        3
# 122758        3
# 122784        3
# 122795        3
# 122796        3
#
# [15362 rows x 28 columns]

# %%
sns.countplot(x='Cluster', data=cluster_df)
# Out:
# <Axes: xlabel='Cluster', ylabel='count'>

# %%
cluster_df.to_csv("/data/Output/kmeans_clustered_customer_Data.csv")

# %%
import sys
sys.getsizeof(kmean)
# Out:
# 48

# %%
#Saving Scikitlearn models
import joblib
joblib.dump(kmean, "/data/Output/kmeans_model.pkl")
# Out:
# ['/data/Output/kmeans_model.pkl']
